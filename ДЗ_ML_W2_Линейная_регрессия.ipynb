# %% [markdown]
# # Линейные модели: регрессия

# %% [markdown]
# ##Как метрики ведут себя на больших значениях:

# %% [markdown]
# Представьте, что вы работаете в MedTech-команде, которая разрабатывает аналитическую систему для мониторинга пациентов с хроническими заболеваниями.
#
# Система используется клиниками и страховыми компаниями для оценки прогрессирования заболевания:
# *   Выявления пациентов высокого риска;
# *   Выявления пациентов высокого риска;
# *   Планирования медицинских ресурсов;
# *   Принятия решений о дополнительном наблюдении и лечении.
#
# Внутри системы используется ML-модель, которая прогнозирует числовой индекс прогрессирования заболевания пациента через год на основе медицинских и физиологических показателей.
# Чем выше значение прогноза, тем выше риск осложнений и тем дороже ошибка для системы здравоохранения.
#
# > Ранее на семинарах мы с вами рассматривали датасет diabetes и пробовали популярные приемы для того чтобы лучше прогнозировать высокие значения (y > 270).
#
# Далее в этом домашнем задании будем предполагать, что высокие значения таргета соответствуют пациентам с тяжелым течением заболевания, повышенным риском осложнений и высокой клинической значимостью ошибки прогноза.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
x_full, y_full = load_diabetes(return_X_y=True)
n_samples, n_features = x_full.shape

# %% [markdown]
# **Перед тем как перейти к заданиям, вспомним, как менялось качество модели при работе с высокими значениями таргета и при применении разных преобразований.**
#
# Этот блок нужен для того, чтобы зафиксировать важный момент: метрики и способ взвешивания ошибок могут радикально менять то, на каких объектах модель начинает «сфокусироваться» и какие ошибки для неё становятся приоритетными.
#
# **Далее эти наблюдения будут использованы в самом задании.**
#
# **Важно:** Все вопросы/подзадачи внутри домашнего задания должны быть выполнены в полном объеме; частично выполненные задания приниматься не будут.

# %% [markdown]
# **Напомним какой получался MAPE на наблюдениях с большими значениями y:**
# *   MAPE без логарифмирования 0.24,
# *   после логарифмирования 0.26,
# *   после преобразования Бокса-Кокса 0.25
#
# **С MSE картина обстояла еще более драматично:**
# *   без логарифмирования 5928.76
# *   после логарифмирования 7614.72
# *   после преобразования Бокса-Кокса 7028.17

# %% [markdown]
# > **Важно:** на семинаре мы и обучались и измеряли качество на всей выборке. Здесь сначала поступим так же

# %% [markdown]
# Что же делать в таком случае?
#
# Выходов не менее двух:
#
# 1. Использовать другую метрику чтобы оценивать результаты под другим углом – это не изменит предсказания модели, но может оказаться, что модель и так уже приемлемо работает (MRAE, MDAPE, MASE, eB);
# 2. Использовать другую функцию потерь – так, чтобы минимизировать ошибку в области больших значениях таргета. Здесь частный случай – взвесить наблюдения пропорционально таргету.

# %% [markdown]
# Давайте совместим оба пункта и в нашем SGD-классе будем оптимизировать сразу MAPE :

# %%
rng = np.random.default_rng(seed=121)
class sgd_lecture_linear:
  def __init__(self, rng, MAX_ITER = 100_000):
    self.MAX_ITER = MAX_ITER
    self.w = None
    self.w0 = rng.normal()
    self.loss = None
    return

  def _f(self, x):
    assert len(x) == len(self.w)
    return np.dot(self.w, x) + self.w0

  def _loss_mse(self, x, y):
    return (y - self._f(x)) ** 2

  def _der_loss(self, x, y):
    if self.loss == 'MSE':
      return -(y - self._f(x)) * x

  def fit(self, X_train, y_train, loss = 'MSE'):
    self.loss = loss
    self.w = rng.normal(size=X_train.shape[1])
    step = 0.01
    for k in range(self.MAX_ITER):
      rand_index = rng.integers(0, X_train.shape[0] - 1)
      x = np.array(X_train)[rand_index]
      y = np.array(y_train)[rand_index]
      if k % 10000 == 0:
         step = step / 2
      self.partial_fit(x, y, step)

  def partial_fit(self, x, y, step = 0.01):
    loss = self.loss
    if not self.w.any():
      self.w = rng.normal(len(x))
    dl = self._der_loss(x, y)
    self.w -= step * dl
    if self.loss == 'MSE':
      self.w0 -= - step * (y - self._f(x))

  def predict_proba(self, x):
    x = np.array(x)
    preds = []
    pred_fuction = None

    if self.loss in ['MSE']:
      pred_fuction = self._f
    for x_curr in x:
      preds.append(pred_fuction(x_curr))
    return preds

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as mape

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_full, y_full)
print(f'{mape(y_full, sgd.predict_proba(x_full)):.2f}')
# Out:
# 0.50

# %% [markdown]
# Давайте посмотрим на MAPE:

# %% [markdown]
# $$
# MAPE\_loss = \sum_i{\frac{|y_i - a_i|}{|y_i|}}
# $$

# %% [markdown]
# от MAE он отличается лишь весами, обратно пропорциональными таргету:
#
# $$
# MAE\_loss = \sum_i{|y_i - a_i|}
# $$

# %% [markdown]
# давайте обучим взвешенный MSE:

# %%
class sgd_lecture_linear:
  def __init__(self, rng, MAX_ITER = 50_000, sample_weights = None):
    self.MAX_ITER = MAX_ITER
    self.w = None
    self.w0 = rng.normal()
    self.loss = None
    self.epsilon = 1e-10
    return

  def _f(self, x):
    assert len(x) == len(self.w)
    return np.dot(self.w, x) + self.w0

  def _loss_mse(self, x, y):
    return (y - self._f(x)) ** 2

  def _der_loss(self, x, y, weight = 1):
      return -(y - self._f(x)) * x * weight

  def fit(self, X_train, y_train, loss = 'MSE', weights = None):
    self.loss = loss
    self.w = rng.normal(size=X_train.shape[1])
    step = 0.01
    if loss == 'MSE':
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step)
    elif loss == 'MSE_weighted':
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        weight = np.array(weights)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step, weight = weight)

  def partial_fit(self, x, y, step = 0.01, weight = 1):
    loss = self.loss
    if not self.w.any():
      self.w = rng.normal(len(x))
    dl = self._der_loss(x, y, weight = weight)
    self.w -= step * dl
    if self.loss == 'MSE':
      self.w0 -= - step * (y - self._f(x))
    if self.loss == 'MSE_weighted':
      self.w0 -= - step * (y - self._f(x)) * weight

  def predict_proba(self, x):
    x = np.array(x)
    preds = []
    pred_fuction = None

    if self.loss in ['MSE', 'MSE_weighted']:
      pred_fuction = self._f
    for x_curr in x:
      preds.append(pred_fuction(x_curr))
    return preds

# %%
sgd_mape = sgd_lecture_linear(rng)
weights =  (y_full - min(y_full)) / (max(y_full) - min(y_full)) + 0.1
weights = 1 / weights
sgd_mape.fit(x_full, y_full, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_full, sgd_mape.predict_proba(x_full)):.2f}')
# Out:
# 0.38

# %% [markdown]
# **Ого! MAPE сильно упал! это здорово!**
#
# Давайте проверим что и в честном train-test split эффект сохранится:

# %%
df = pd.DataFrame(x_full)
df['target'] = y_full
test_size = 0.3
random_state = 43
x_train, x_test, y_train, y_test = train_test_split(df.drop(['target'], axis = 1), df['target'], test_size=test_size, random_state=random_state)

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_train, y_train)
print(f'{mape(y_test, sgd.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении с обычным MSE')
sgd_mse_w = sgd_lecture_linear(rng)
weights =  (y_train - min(y_train)) / (max(y_train) - min(y_train)) + 0.03 # чтобы не делить на ноль
weights = 1 / weights
sgd_mse_w.fit(x_train, y_train, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_test, sgd_mse_w.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении на weighted MSE')
# Out:
# 0.50  -- MAPE на тесте при обучении с обычным MSE
# 0.35  -- MAPE на тесте при обучении на weighted MSE

# %% [markdown]
# Давайте померяем как стали прогнозироваться объекты с большими значениями таргета:

# %%
df_test = pd.DataFrame(y_test, columns = ['target'])
df_test['pred_MSE'] = sgd.predict_proba(x_test)
df_test['pred_MSE_weighted'] = sgd_mse_w.predict_proba(x_test)
print(mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE']), ' -- MAPE на тесте при обучении с обычным MSE на больших таргетах (>270)')
print(mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE_weighted']), ' -- MAPE на тесте при обучении с weighted MSE на больших таргетах (>270)')
# Out:
# 0.3633930826428124  -- MAPE на тесте при обучении с обычным MSE на больших таргетах (>270)
# 0.4531585259572989  -- MAPE на тесте при обучении с weighted MSE на больших таргетах (>270)

# %% [markdown]
# **Стало даже хуже!**
#
# Давайте попробуем поменять веса у таких объектов:

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_train, y_train)
print(f'{mape(y_test, sgd.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении с обычным MSE')
sgd_mse_w = sgd_lecture_linear(rng)
weights =  (y_train - min(y_train)) / (max(y_train) - min(y_train)) + 0.03 # чтобы не делить на ноль
weights = 1 / weights
for idx, y in zip(weights.index, y_train):
  if y > 270:
    weights[idx] = weights[idx] * 10

sgd_mse_w.fit(x_train, y_train, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_test, sgd_mse_w.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении на weighted MSE')

df_test = pd.DataFrame(y_test, columns = ['target'])
df_test['pred_MSE'] = sgd.predict_proba(x_test)
df_test['pred_MSE_weighted'] = sgd_mse_w.predict_proba(x_test)
mape_ordinary = mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE'])
mape_weighted_mse = mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE_weighted'])
print(f'{mape_ordinary:.2f}', ' -- MAPE на тесте (только на больших таргетах) при обучении с обычным MSE на больших таргетах (>270)')
print(f'{mape_weighted_mse:.2f}', ' -- MAPE на тесте (только на больших таргетах) при обучении с weighted MSE на больших таргетах (>270)')
# Out:
# 0.50  -- MAPE на тесте при обучении с обычным MSE
# 0.39  -- MAPE на тесте при обучении на weighted MSE
# 0.37  -- MAPE на тесте (только на больших таргетах) при обучении с обычным MSE на больших таргетах (>270)
# 0.21  -- MAPE на тесте (только на больших таргетах) при обучении с weighted MSE на больших таргетах (>270)

# %% [markdown]
# **Кажется, ошибка на больших значениях существенно снизилась!**
#
# Давайте нарисуем это:

# %%
import plotly.express as px
import plotly.graph_objs as go

df = pd.DataFrame(dict(
    series=np.concatenate((["Таргет"] * len(y_test), ["Предсказание через оптимизацию MSE"] * len(y_test))),
    data=np.concatenate((y_test, df_test['pred_MSE']))
))


fig = px.histogram(df, x="data", color="series", barmode="overlay")
fig.update_layout(
                  title="Распределение таргетов и предиктов"
                  , xaxis_title="Таргеты"
                  , yaxis_title="Число"
                  , margin=dict(l=0, r=0, t=50, b=0)
                  , height=600
                  , width=900
                  , font_family="Arial"
                  , font_color="black"
                  , font_size = 20
                  , title_font_family="Times New Roman"
                  , title_font_size = 20
                  , title_font_color="black"
                  , separators=", .*"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52ae8fbb-6491-45ec-b16b-a2ef4a8b79b9" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52ae8fbb-6491-45ec-b16b-a2ef4a8b79b9")) {                    Plotly.newPlot(                        "52ae8fbb-6491-45ec-b16b-a2ef4a8b79b9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Таргет\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Таргет","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Таргет","offsetgroup":"Таргет","orientation":"v","showlegend":true,"x":[71.0,72.0,235.0,277.0,109.0,61.0,109.0,78.0,66.0,192.0,52.0,173.0,97.0,216.0,68.0,232.0,237.0,68.0,262.0,116.0,220.0,51.0,131.0,195.0,63.0,144.0,248.0,71.0,52.0,90.0,171.0,77.0,198.0,77.0,167.0,74.0,72.0,201.0,128.0,60.0,257.0,85.0,57.0,151.0,281.0,84.0,80.0,242.0,70.0,53.0,296.0,257.0,161.0,59.0,65.0,217.0,102.0,91.0,261.0,243.0,281.0,144.0,92.0,178.0,270.0,170.0,71.0,179.0,45.0,274.0,182.0,178.0,97.0,58.0,125.0,67.0,116.0,202.0,90.0,281.0,99.0,311.0,259.0,283.0,168.0,191.0,206.0,262.0,155.0,202.0,55.0,202.0,42.0,214.0,173.0,118.0,90.0,129.0,151.0,111.0,53.0,85.0,109.0,200.0,152.0,252.0,155.0,178.0,128.0,258.0,124.0,265.0,189.0,139.0,70.0,302.0,47.0,90.0,200.0,306.0,94.0,31.0,272.0,215.0,137.0,148.0,140.0,99.0,89.0,198.0,242.0,200.0,237.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Предсказание через оптимизацию MSE\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Предсказание через оптимизацию MSE","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Предсказание через оптимизацию MSE","offsetgroup":"Предсказание через оптимизацию MSE","orientation":"v","showlegend":true,"x":[138.42474571466533,132.82514672032224,166.74851024506998,199.63416606429251,161.0143343932514,118.5051311300727,167.1304334237717,138.12151152754683,140.17971636773296,185.50635249508852,121.25171737881709,182.0483282751134,148.9846390867287,147.35619357379963,130.16600083534829,171.7184773975556,161.44319526219468,174.27576556614844,163.4340956899196,166.46347263935388,182.8249131869643,110.17984733962271,174.30305681315969,172.9908216750684,129.47629370633575,130.07393021268982,199.56956875713513,121.38124527672596,111.69262337178222,157.75183179975707,175.02754429341275,107.47940718269402,166.487692886002,120.09329281332097,160.49577207699627,148.40129523036606,129.62803565736584,124.58859018950345,115.97858757271933,129.44008499289663,171.29419652498757,150.99925870548304,109.74513464126969,156.75080439800837,188.20989483584282,153.322182894099,139.2850110703197,220.95255515189695,110.89358322904961,143.93539800710042,177.10892520857055,174.48304268637256,164.69489889243007,114.69165968465074,113.49134493433894,167.4350111386873,130.38306018538057,166.86341926355857,180.955848535032,209.873567122848,195.07115482009493,174.5440871135652,137.899669656287,138.1204409976417,179.96420909829695,156.87597751561518,120.19398694112024,129.06660828968546,108.01043972271593,186.29793674445037,131.17904265433538,164.7032610546119,142.19599074683723,158.55523473068817,113.96562676296026,141.94516684760404,114.4733917441414,165.1984147972167,107.29760830993486,176.25231015983502,103.50920509406696,171.25823304667207,183.4177888336343,157.52676055739525,167.6504005483589,155.18094905911678,153.19967770657718,167.40909351732262,145.03655822641045,161.1645384549765,110.17144478787023,159.71325982103704,117.76082705945387,134.68696395403325,169.760354591986,159.92747883794917,119.2426115378163,143.40744102289207,169.74887411791806,165.52966223809668,135. ...

# %%
import plotly.express as px
import plotly.graph_objs as go

df = pd.DataFrame(dict(
    series=np.concatenate((["Таргет"] * len(y_test), ["Предсказание через взвешенный MSE"] * len(y_test))),
    data=np.concatenate((y_test, df_test['pred_MSE_weighted']))
))


fig = px.histogram(df, x="data", color="series", barmode="overlay")
fig.update_layout(
                  title="Распределение таргетов и предиктов"
                  , xaxis_title="Таргеты"
                  , yaxis_title="Число"
                  , margin=dict(l=0, r=0, t=50, b=0)
                  , height=600
                  , width=900
                  , font_family="Arial"
                  , font_color="black"
                  , font_size = 20
                  , title_font_family="Times New Roman"
                  , title_font_size = 20
                  , title_font_color="black"
                  , separators=", .*"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c29e0988-e9b8-40ec-a0f0-ce58c1664198" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c29e0988-e9b8-40ec-a0f0-ce58c1664198")) {                    Plotly.newPlot(                        "c29e0988-e9b8-40ec-a0f0-ce58c1664198",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Таргет\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Таргет","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Таргет","offsetgroup":"Таргет","orientation":"v","showlegend":true,"x":[71.0,72.0,235.0,277.0,109.0,61.0,109.0,78.0,66.0,192.0,52.0,173.0,97.0,216.0,68.0,232.0,237.0,68.0,262.0,116.0,220.0,51.0,131.0,195.0,63.0,144.0,248.0,71.0,52.0,90.0,171.0,77.0,198.0,77.0,167.0,74.0,72.0,201.0,128.0,60.0,257.0,85.0,57.0,151.0,281.0,84.0,80.0,242.0,70.0,53.0,296.0,257.0,161.0,59.0,65.0,217.0,102.0,91.0,261.0,243.0,281.0,144.0,92.0,178.0,270.0,170.0,71.0,179.0,45.0,274.0,182.0,178.0,97.0,58.0,125.0,67.0,116.0,202.0,90.0,281.0,99.0,311.0,259.0,283.0,168.0,191.0,206.0,262.0,155.0,202.0,55.0,202.0,42.0,214.0,173.0,118.0,90.0,129.0,151.0,111.0,53.0,85.0,109.0,200.0,152.0,252.0,155.0,178.0,128.0,258.0,124.0,265.0,189.0,139.0,70.0,302.0,47.0,90.0,200.0,306.0,94.0,31.0,272.0,215.0,137.0,148.0,140.0,99.0,89.0,198.0,242.0,200.0,237.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Предсказание через взвешенный MSE\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Предсказание через взвешенный MSE","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Предсказание через взвешенный MSE","offsetgroup":"Предсказание через взвешенный MSE","orientation":"v","showlegend":true,"x":[115.89134630066927,91.22858527067724,172.3926676655377,280.7635404992093,171.66525914482227,85.75906001453707,201.49899062550787,107.32033479787432,113.16777317264729,244.73588214040672,62.54328780242771,237.77805848339085,129.78757403601625,133.73366560941085,101.28489652633704,193.06762661089573,162.28647781907043,200.6644481251614,184.11506008979336,164.68362815656678,208.0930843430911,37.90496010051716,207.24218836567843,212.71004151609833,76.60694741297836,97.4375530772364,259.1964322384225,69.19038746438589,39.0657222227764,165.3149184679014,169.68364710522928,35.08449444173921,169.5989726861981,56.499846400292896,187.36373793806422,131.447055024994,94.17881393387123,88.84477490010649,58.08450185463042,95.98959296559205,185.2691519631763,176.11628441290534,32.79626158887622,157.19418102442052,273.0373986714497,132.10522913213566,89.03103321998158,331.53573578385146,36.42584167596385,121.22570666121416,214.69240810961549,218.8306927539731,187.84284747965,56.57267843005906,65.78433018752061,171.5025672336183,85.4685380729828,152.95501848872365,240.96920057524187,294.37347055492774,253.63646435503563,188.66972102016032,107.50114276617964,117.25640009955794,224.247481084757,140.5825996130702,66.92058431424404,92.18803256535325,21.425340560509667,245.9328847149909,107.18766548655631,171.02773919582344,133.5583874044741,160.31394822982293,60.370184734720084,129.50587154741916,37.90294025272257,202.42303261463695,29.49532663672788,237.4669298300591,28.788400734740193,187.48646967125947,231.93401713839177,174.44695817841546,171.4002307784128,175.54454451704672,154.16976072815177,181.87790286276203,142.91795624788458,177.28736796227278,55.02898942936585,152.91860259744746,69.00539036983187,100.71906526648057,198.42611676934345,161.4112572576186,69.13279071052166,144.495852300203,204.5928050990901,180.72945140633988,97.50473243715584,151.2598232023 ...

# %% [markdown]
# ## Задание 2.1:
#
# Представьте, что вы рассматриваете возможность внедрить в MedTech-продукт модель, которая оптимизируется напрямую под клинически значимую метрику — MAPE, поскольку именно относительная ошибка лучше отражает медицинские риски.
#
# Попробуйте обучить модель непосредственно на MAPE и оцените полученное значение MAPE на тестовой выборке, которая соответствует новым, ранее не наблюдавшимся пациентам.
#
# Дополните недостающие части кода, чтобы реализовать обучение модели на MAPE, и обучите модель на тренировочной выборке.

# %%
rng = np.random.default_rng(seed=121)
class sgd_lecture_linear:
  def __init__(self, rng, MAX_ITER = 50_000, sample_weights = None):
    self.MAX_ITER = MAX_ITER
    self.w = None
    self.w0 = rng.normal()
    self.loss = None
    self.epsilon = 1e-10
    return

  def _f(self, x):
    assert len(x) == len(self.w)
    return np.dot(self.w, x) + self.w0

  def _loss_mse(self, x, y):
    return (y - self._f(x)) ** 2

  def _der_loss(self, x, y, weight = 1):
    if self.loss in ['MSE', 'MSE_weighted']:
      return -(y - self._f(x)) * x * weight
    elif self.loss == 'MAPE':
      return -np.sign(y - self._f(x)) * x * weight / (np.abs(y) + 1e-8)

  def fit(self, X_train, y_train, loss = 'MSE', weights = None):
    self.loss = loss
    self.w = rng.normal(size=X_train.shape[1])
    step = 0.01
    if loss == 'MSE':
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step)
    elif loss in ['MSE_weighted', 'MAPE']:
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        weight = np.array(weights)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step, weight = weight)

  def partial_fit(self, x, y, step = 0.01, weight = 1):
    loss = self.loss
    if not self.w.any():
      self.w = rng.normal(len(x))
    dl = self._der_loss(x, y, weight = weight)
    self.w -= step * dl
    if self.loss == 'MSE':
      self.w0 -= - step * (y - self._f(x))
    elif self.loss == 'MSE_weighted':
      self.w0 -= - step * (y - self._f(x)) * weight
    elif self.loss == 'MAPE':
      self.w0 -= - step * np.sign(y - self._f(x)) * weight / (np.abs(y) + 1e-8)

  def predict_proba(self, x):
    x = np.array(x)
    preds = []
    pred_fuction = None

    if self.loss in ['MSE', 'MSE_weighted','MAPE']:
      pred_fuction = self._f
    for x_curr in x:
      preds.append(pred_fuction(x_curr))
    return preds

# %%
sgd_mape = sgd_lecture_linear(rng)
weights = np.full_like(x_train[0], 100000)
# weights = y_train * 1000
# weights =  (y_train - min(y_train)) / (max(y_train) - min(y_train)) + 0.03 # чтобы не делить на ноль

sgd_mape.fit(x_train, y_train, loss = 'MAPE', weights = weights)
print(f'{mape(y_test, sgd_mape.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении на MAPE')
print(f'{mape(y_train, sgd_mape.predict_proba(x_train)):.2f}', ' -- MAPE на train при обучении на MAPE')
df_test['pred_MAPE'] = sgd_mape.predict_proba(x_test)
# Out:
# 0.34  -- MAPE на тесте при обучении на MAPE
# 0.35  -- MAPE на train при обучении на MAPE

# %%
# посмотрим распределение
import plotly.express as px
import plotly.graph_objs as go

df = pd.DataFrame(dict(
    series=np.concatenate((["Таргет"] * len(y_test), ["Предсказание через MAPE"] * len(y_test))),
    data=np.concatenate((y_test, df_test['pred_MAPE']))
))


fig = px.histogram(df, x="data", color="series", barmode="overlay")
fig.update_layout(
                  title="Распределение таргетов и предиктов"
                  , xaxis_title="Таргеты"
                  , yaxis_title="Число"
                  , margin=dict(l=0, r=0, t=50, b=0)
                  , height=600
                  , width=900
                  , font_family="Arial"
                  , font_color="black"
                  , font_size = 20
                  , title_font_family="Times New Roman"
                  , title_font_size = 20
                  , title_font_color="black"
                  , separators=", .*"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="879a6c23-6ba3-44b2-986e-f2a0ac1f7857" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("879a6c23-6ba3-44b2-986e-f2a0ac1f7857")) {                    Plotly.newPlot(                        "879a6c23-6ba3-44b2-986e-f2a0ac1f7857",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Таргет\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Таргет","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Таргет","offsetgroup":"Таргет","orientation":"v","showlegend":true,"x":[71.0,72.0,235.0,277.0,109.0,61.0,109.0,78.0,66.0,192.0,52.0,173.0,97.0,216.0,68.0,232.0,237.0,68.0,262.0,116.0,220.0,51.0,131.0,195.0,63.0,144.0,248.0,71.0,52.0,90.0,171.0,77.0,198.0,77.0,167.0,74.0,72.0,201.0,128.0,60.0,257.0,85.0,57.0,151.0,281.0,84.0,80.0,242.0,70.0,53.0,296.0,257.0,161.0,59.0,65.0,217.0,102.0,91.0,261.0,243.0,281.0,144.0,92.0,178.0,270.0,170.0,71.0,179.0,45.0,274.0,182.0,178.0,97.0,58.0,125.0,67.0,116.0,202.0,90.0,281.0,99.0,311.0,259.0,283.0,168.0,191.0,206.0,262.0,155.0,202.0,55.0,202.0,42.0,214.0,173.0,118.0,90.0,129.0,151.0,111.0,53.0,85.0,109.0,200.0,152.0,252.0,155.0,178.0,128.0,258.0,124.0,265.0,189.0,139.0,70.0,302.0,47.0,90.0,200.0,306.0,94.0,31.0,272.0,215.0,137.0,148.0,140.0,99.0,89.0,198.0,242.0,200.0,237.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Предсказание через MAPE\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Предсказание через MAPE","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Предсказание через MAPE","offsetgroup":"Предсказание через MAPE","orientation":"v","showlegend":true,"x":[96.71436916039977,78.6400597181632,136.32465903544477,209.17886233296113,171.4274815321233,87.31317907711711,145.17496741555692,118.77260721329502,94.69410324597891,194.98363005268928,51.77222828693809,172.32499954058477,101.61603599285506,106.0127902174492,94.690857994553,146.60975373311175,117.32079069642253,165.2662801073539,152.53030255094063,128.48783932777152,143.50608537415133,71.7908756784154,133.37187646689569,172.08564077232035,79.39908787975455,89.54804796905886,205.3667587733683,66.73558750118752,54.769227030919765,155.09433833914062,132.201294564498,58.86069603082562,125.79751166064223,61.15830669282771,144.87618846961757,102.84590088551164,86.2626455313737,80.80488471701825,56.554088490979915,89.99250248707077,143.33272113594404,136.6450661702793,54.71250611416248,131.50123613609398,210.94076555200937,100.97287608388217,61.917891536315565,249.29095628167028,52.45996466140164,97.27749256154539,159.30403909389085,149.24431339011068,162.67426420857254,62.89361255866094,82.28993225139425,127.49330242968865,83.18406675514626,123.26372958520084,166.54644503129873,211.7766854244184,180.2117668348643,141.28521683270498,101.56867294615472,107.81454077555026,159.46937825180373,113.13686327909446,64.52714331956054,91.32272558042033,20.14489645030565,164.5755608256589,81.82102233594955,116.75369583584622,116.74334864155456,127.29053830342744,86.02459495597707,93.43978033502347,37.75098557866153,162.47077830938105,43.739390465079666,194.80388396368937,42.66113403132343,131.37061233489118,178.0413741939741,142.66551549686136,127.39313621273628,141.22366523596577,133.56758614303993,124.62642627222682,117.38284121727192,133.2639287303568,66.89994339990022,139.084195003692,66.38190234192471,97.96697506211079,156.23243931366102,111.96310560307595,82.79563251898776,118.35297317157945,160.04871786282115,138.85821108932518,78.48755565666353,123.00493899245201,96.10485627217794,113.156422567 ...

# %% [markdown]
# ## Задание 2.2:
#
# Выберите правильный вариант ответа на основании выполненного кода выше.

# %% [markdown]
# В какой интервал попадает MAPE на тесте при обучении на MAPE?
#
# 1.   0.34 – 0.37
# 2.   0.37 – 0.40
# 3.   0.41 – 0.43
# 4.   0.44 – 0.47

# %% [markdown]
# **Ответ:** 1

# %% [markdown]
# ---
#
#
# *Перед отправкой задания убедитесь, что реализация обучения и вычисления метрики выполнены корректно, масштабирование таргета и обратные преобразования согласованы между собой, а итоговое значение MAPE на тестовой выборке получено из корректно работающего и воспроизводимого кода.*
